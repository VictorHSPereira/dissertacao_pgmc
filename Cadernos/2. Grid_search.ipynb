# %% [markdown]
# # Imports necessários

# %% [markdown]
# ## Bibliotecas

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from permetrics.regression import RegressionMetric
from datetime import datetime
import matplotlib.pyplot as plt 

import statistics as st
import sys
import math
import pandas as pd
import numpy as np
sys.path.insert(1, '..\Modelo')

from sklearn.model_selection import ParameterGrid
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from lssvr import LSSVR
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from eTS import eTS
from Simpl_eTS import Simpl_eTS
from exTS import exTS
from ePL import ePL
from eMG import eMG
from ePL_plus import ePL_plus
from ePL_KRLS_DISCO import ePL_KRLS_DISCO
from NMFIS import NMFIS
from NTSK import NTSK
from GEN_NMFIS import GEN_NMFIS
from GEN_NTSK import GEN_NTSK

# Neural Network
# Model
from keras.models import Sequential, Model
# Layers
from keras.layers import Input, InputLayer, Dense, Dropout, Conv1D, GRU, LSTM, MaxPooling1D, Flatten, SimpleRNN
#from tensorflow.keras.layers import Input
from tcn import TCN
# Optimizers
from keras.optimizers import SGD, Adam
# Save network
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Importando a série

# %%
df = pd.read_csv("../Dados/Dados refinados/timeseries.csv", index_col= 0)
df.head(10)
# Out:
#    mes      hora_sin  hora_cos  dia_semana_sin  dia_semana_cos  \
# 0    1  9.659258e-01 -0.258819       -0.974928       -0.222521
# 1    1  8.660254e-01 -0.500000       -0.974928       -0.222521
# 2    1  8.660254e-01 -0.500000       -0.974928       -0.222521
# 3    1  7.071068e-01 -0.707107       -0.974928       -0.222521
# 4    1  7.071068e-01 -0.707107       -0.974928       -0.222521
# 5    1  5.000000e-01 -0.866025       -0.974928       -0.222521
# 6    1  5.000000e-01 -0.866025       -0.974928       -0.222521
# 7    1  2.588190e-01 -0.965926       -0.974928       -0.222521
# 8    1  2.588190e-01 -0.965926       -0.974928       -0.222521
# 9    1  1.224647e-16 -1.000000       -0.974928       -0.222521
#
#    QTD_VEICULOS_USINA  primeira_quinzena  feriado  fim_semana    lag_1h  \
# 0                  21                  1        0           1  8.840000
# 1                  23                  1        0           1  8.885333
# 2                  28                  1        0           1  8.484063
# 3                  35                  1        0           1  8.150294
# 4                  32                  1        0           1  7.830648
# 5                  29                  1        0           1  7.581667
# 6                  29                  1        0           1  7.362583
# 7                  30                  1        0           1  7.186905
# 8                  32                  1        0           1  6.978712
# 9                  31                  1        0           1  6.898043
#
#      lag_1d    lag_7d       TPV
# 0  6.538125  2.220000  8.484063
# 1  6.293235  2.220000  8.150294
# 2  6.093056  2.476667  7.830648
# 3  5.945197  2.605000  7.581667
# 4  5.780604  2.682000  7.362583
# 5  5.620099  2.733333  7.186905
# 6  5.523352  2.770000  6.978712
# 7  5.412337  2.797500  6.898043
# 8  5.309656  2.818889  6.772153
# 9  5.209537  2.808000  6.632307

# %% [markdown]
# # Transformação de dados

# %% [markdown]
# ## Normalizando os dados

# %%
#Separando X e y

X = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
#Definindo o scalers
scaler_X, scaler_y = MinMaxScaler(),MinMaxScaler()

#fit
# scaler_X.fit(X[['mes','QTD_VEICULOS_USINA']])
scaler_X.fit(X)
scaler_y.fit(pd.DataFrame(y))

#transform

# X[['mes','QTD_VEICULOS_USINA']] = scaler_X.transform(X[['mes','QTD_VEICULOS_USINA']])
X = pd.DataFrame(scaler_X.transform(X), columns= X.columns)
y = scaler_y.transform(pd.DataFrame(y))

# %%
cat_cols = ['mes', 'primeira_quinzena', 'feriado', 'fim_semana']

for col in cat_cols:
    X[col] = X[col].astype('category')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10271 entries, 0 to 10270
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mes                 10271 non-null  category
#  1   hora_sin            10271 non-null  float64
#  2   hora_cos            10271 non-null  float64
#  3   dia_semana_sin      10271 non-null  float64
#  4   dia_semana_cos      10271 non-null  float64
#  5   QTD_VEICULOS_USINA  10271 non-null  float64
#  6   primeira_quinzena   10271 non-null  category
#  7   feriado             10271 non-null  category
#  8   fim_semana          10271 non-null  category
#  9   lag_1h              10271 non-null  float64
#  10  lag_1d              10271 non-null  float64
#  11  lag_7d              10271 non-null  float64
# dtypes: category(4), float64(8)
# memory usage: 682.9 KB

# %% [markdown]
# ## Separação train, val, test

# %%
X.shape[0]
# Out:
# 10271

# %%
# Separando os índices do treino, validacao e teste

index_train = round(X.shape[0]*0.5)
index_val = round(X.shape[0]*0.3) + index_train

#Separando as bases
X_train, y_train = X.values[:index_train], y[:index_train]
X_val, y_val = X.values[index_train:index_val], y[index_train:index_val]
X_test, y_test =  X.values[index_val:], y[index_val:]


y_test = scaler_y.inverse_transform(y_test)

# %% [markdown]
# # Modelagem

# %% [markdown]
# ## Modelos Clássicos

# %%
# Summary
columns = ["Model_Name", "NRMSE", "NDEI", "MAPE", "Rules", "Best_Params"]
results = pd.DataFrame(columns = columns)

# Predictions
predictions = pd.DataFrame(y_test, columns= ['y_test'])

# %% [markdown]
# ### KNN

# %%
Model_Name = "KNN"

# Define Grid Search parameters
parameters = {'n_neighbors': [2, 3, 4, 5, 10, 20]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )
  

    # Optimize parameters
    KNN = KNeighborsRegressor(**param)
    KNN.fit(X_train,y_train)
    # Make predictions
    y_pred = KNN.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_KNN_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]

KNN = KNeighborsRegressor(**best_KNN_params)
KNN.fit(new_X_train, new_y_train)

# Make predictions
y_pred = KNN.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics

# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)


print(f'\nBest params: \n{best_KNN_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_KNN_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/6] {'n_neighbors': 2}
# [2/6] {'n_neighbors': 3}
# [3/6] {'n_neighbors': 4}
# [4/6] {'n_neighbors': 5}
# [5/6] {'n_neighbors': 10}
# [6/6] {'n_neighbors': 20}
#
# Results for KNN:
#
#
# RMSE: 1.5303760205592174
# NRMSE: 0.5508163043897
# NDEI: 0.5430557275858096
# MAE: 0.8654752944122002
# MAPE: 0.44578320258869514
# Rules: -
#
# Best params:
# {'n_neighbors': 5}
# C:\Users\thevh\AppData\Local\Temp\ipykernel_21764\92911531.py:71: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, newrow], ignore_index=True)

# %% [markdown]
# ### Regression Tree

# %%
Model_Name = "Regression Tree"

# Define Grid Search parameters
parameters = {'max_depth': [2, 4, 6, 8, 10, 20, 30, 50, 100]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    RT = DecisionTreeRegressor(**param)
    RT.fit(X_train,y_train)
    # Make predictions
    y_pred = RT.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_RT_params = param

# Optimized parameters
new_X_train, new_y_train = X.values[:index_val], y[:index_val]

RT = DecisionTreeRegressor(**best_RT_params)
RT.fit(new_X_train,new_y_train)
# Make predictions
y_pred = RT.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred


# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)

print(f'\nBest params: \n{best_RT_params}')
   
RT_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_RT_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/9] {'max_depth': 2}
# [2/9] {'max_depth': 4}
# [3/9] {'max_depth': 6}
# [4/9] {'max_depth': 8}
# [5/9] {'max_depth': 10}
# [6/9] {'max_depth': 20}
# [7/9] {'max_depth': 30}
# [8/9] {'max_depth': 50}
# [9/9] {'max_depth': 100}
#
# Results for Regression Tree:
#
#
# RMSE: 0.5530319159068365
# NRMSE: 0.1971088526031491
# NDEI: 0.19624402462946217
# MAE: 0.25470445448108253
# MAPE: 0.1025038571061237
# Rules: -
#
# Best params:
# {'max_depth': 6}

# %% [markdown]
# ### SVM

# %%
Model_Name = "SVM"

# Define Grid Search parameters
parameters = {'kernel': ['linear', 'rbf', 'sigmoid'], 'C':[0.01,0.1,1,10], 'gamma': [0.01,0.5,1,10,50]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )
    
    # Optimize parameters
    SVM = SVR(**param)
    SVM.fit(X_train,y_train.ravel())
    # Make predictions
    y_pred = SVM.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_SVM_params = param

# # Use best parameters1 to save time looking for best parameters2
# parameters2 = {'kernel': ['poly'], 'C':[best_SVM_params['C']], 'gamma': [best_SVM_params['gamma']], 'degree': [2,3]}

# grid2 = ParameterGrid(parameters2)

# for param in grid2:
    
#     #print(param)
    
#     # Optimize parameters
#     SVM = SVR(**param)
#     SVM.fit(X_train,y_train)
#     # Make predictions
#     y_pred = SVM.predict(X_val)
#     
    
#     # Calculating the error metrics
#     # Compute the Root Mean Square Error
#     RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
#     if RMSE < lower_rmse:
#         lower_rmse = RMSE
#         best_SVM_params = param


# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]

SVM = SVR(**best_SVM_params)
SVM.fit(new_X_train,new_y_train.ravel())
# Make predictions
y_pred = SVM.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error

RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)

SVM_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

print(f'\n{best_SVM_params}')
   
# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_SVM_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/60] {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# [2/60] {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# [3/60] {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# [4/60] {'C': 0.01, 'gamma': 0.5, 'kernel': 'linear'}
# [5/60] {'C': 0.01, 'gamma': 0.5, 'kernel': 'rbf'}
# [6/60] {'C': 0.01, 'gamma': 0.5, 'kernel': 'sigmoid'}
# [7/60] {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
# [8/60] {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# [9/60] {'C': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
# [10/60] {'C': 0.01, 'gamma': 10, 'kernel': 'linear'}
# [11/60] {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
# [12/60] {'C': 0.01, 'gamma': 10, 'kernel': 'sigmoid'}
# [13/60] {'C': 0.01, 'gamma': 50, 'kernel': 'linear'}
# [14/60] {'C': 0.01, 'gamma': 50, 'kernel': 'rbf'}
# [15/60] {'C': 0.01, 'gamma': 50, 'kernel': 'sigmoid'}
# [16/60] {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# [17/60] {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# [18/60] {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# [19/60] {'C': 0.1, 'gamma': 0.5, 'kernel': 'linear'}
# [20/60] {'C': 0.1, 'gamma': 0.5, 'kernel': 'rbf'}
# [21/60] {'C': 0.1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# [22/60] {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# [23/60] {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# [24/60] {'C': 0.1, 'gamma': 1, 'kernel': 'sigmoid'}
# [25/60] {'C': 0.1, 'gamma': 10, 'kernel': 'linear'}
# [26/60] {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
# [27/60] {'C': 0.1, 'gamma': 10, 'kernel': 'sigmoid'}
# [28/60] {'C': 0.1, 'gamma': 50, 'kernel': 'linear'}
# [29/60] {'C': 0.1, 'gamma': 50, 'kernel': 'rbf'}
# [30/60] {'C': 0.1, 'gamma': 50, 'kernel': 'sigmoid'}
# [31/60] {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# [32/60] {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# [33/60] {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# [34/60] {'C': 1, 'gamma': 0.5, 'kernel': 'linear'}
# [35/60] {'C': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# [36/60] {'C': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# [37/60] {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# [38/60] {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# [39/60] {'C': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# [40/60] {'C': 1, 'gamma': 10, 'kernel': 'linear'}
# [41/60] {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# [42/60] {'C': 1, 'gamma': 10, 'kernel': 'sigmoid'}
# [43/60] {'C': 1, 'gamma': 50, 'kernel': 'linear'}
# [44/60] {'C': 1, 'gamma': 50, 'kernel': 'rbf'}
# [45/60] {'C': 1, 'gamma': 50, 'kernel': 'sigmoid'}
# [46/60] {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# [47/60] {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# [48/60] {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# [49/60] {'C': 10, 'gamma': 0.5, 'kernel': 'linear'}
# [50/60] {'C': 10, 'gamma': 0.5, 'kernel': 'rbf'}
# [51/60] {'C': 10, 'gamma': 0.5, 'kernel': 'sigmoid'}
# [52/60] {'C': 10, 'gamma': 1, 'kernel': 'linear'}
# [53/60] {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# [54/60] {'C': 10, 'gamma': 1, 'kernel': 'sigmoid'}
# [55/60] {'C': 10, 'gamma': 10, 'kernel': 'linear'}
# [56/60] {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# [57/60] {'C': 10, 'gamma': 10, 'kernel': 'sigmoid'}
# [58/60] {'C': 10, 'gamma': 50, 'kernel': 'linear'}
# [59/60] {'C': 10, 'gamma': 50, 'kernel': 'rbf'}
# [60/60] {'C': 10, 'gamma': 50, 'kernel': 'sigmoid'}
#
# Results for SVM:
#
#
# RMSE: 3.3735581147603146
# NRMSE: 1.2758326755185818
# NDEI: 1.1971110576436825
# MAE: 3.2877162890250764
# MAPE: 2.1690629888253965
# Rules: -
#
# {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}

# %% [markdown]
# ### Gradient Boosting Model

# %%
Model_Name = "GB"

# Define Grid Search parameters
parameters = {'learning_rate':[0.01, 0.05, 0.1, 0.5, 0.9], 'n_estimators': [2, 4, 8, 16, 32, 64, 100, 200]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    GB = GradientBoostingRegressor(**param)
    GB.fit(X_train,y_train.ravel())
    # Make predictions
    y_pred = GB.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_GB_params = param


# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
GB = GradientBoostingRegressor(**best_GB_params)
GB.fit(new_X_train,new_y_train)
# Make predictions
y_pred = GB.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)

GB_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

print(f'\n{best_GB_params}')
   
# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_GB_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/40] {'learning_rate': 0.01, 'n_estimators': 2}
# [2/40] {'learning_rate': 0.01, 'n_estimators': 4}
# [3/40] {'learning_rate': 0.01, 'n_estimators': 8}
# [4/40] {'learning_rate': 0.01, 'n_estimators': 16}
# [5/40] {'learning_rate': 0.01, 'n_estimators': 32}
# [6/40] {'learning_rate': 0.01, 'n_estimators': 64}
# [7/40] {'learning_rate': 0.01, 'n_estimators': 100}
# [8/40] {'learning_rate': 0.01, 'n_estimators': 200}
# [9/40] {'learning_rate': 0.05, 'n_estimators': 2}
# [10/40] {'learning_rate': 0.05, 'n_estimators': 4}
# [11/40] {'learning_rate': 0.05, 'n_estimators': 8}
# [12/40] {'learning_rate': 0.05, 'n_estimators': 16}
# [13/40] {'learning_rate': 0.05, 'n_estimators': 32}
# [14/40] {'learning_rate': 0.05, 'n_estimators': 64}
# [15/40] {'learning_rate': 0.05, 'n_estimators': 100}
# [16/40] {'learning_rate': 0.05, 'n_estimators': 200}
# [17/40] {'learning_rate': 0.1, 'n_estimators': 2}
# [18/40] {'learning_rate': 0.1, 'n_estimators': 4}
# [19/40] {'learning_rate': 0.1, 'n_estimators': 8}
# [20/40] {'learning_rate': 0.1, 'n_estimators': 16}
# [21/40] {'learning_rate': 0.1, 'n_estimators': 32}
# [22/40] {'learning_rate': 0.1, 'n_estimators': 64}
# [23/40] {'learning_rate': 0.1, 'n_estimators': 100}
# [24/40] {'learning_rate': 0.1, 'n_estimators': 200}
# [25/40] {'learning_rate': 0.5, 'n_estimators': 2}
# [26/40] {'learning_rate': 0.5, 'n_estimators': 4}
# [27/40] {'learning_rate': 0.5, 'n_estimators': 8}
# [28/40] {'learning_rate': 0.5, 'n_estimators': 16}
# [29/40] {'learning_rate': 0.5, 'n_estimators': 32}
# [30/40] {'learning_rate': 0.5, 'n_estimators': 64}
# [31/40] {'learning_rate': 0.5, 'n_estimators': 100}
# [32/40] {'learning_rate': 0.5, 'n_estimators': 200}
# [33/40] {'learning_rate': 0.9, 'n_estimators': 2}
# [34/40] {'learning_rate': 0.9, 'n_estimators': 4}
# [35/40] {'learning_rate': 0.9, 'n_estimators': 8}
# [36/40] {'learning_rate': 0.9, 'n_estimators': 16}
# [37/40] {'learning_rate': 0.9, 'n_estimators': 32}
# [38/40] {'learning_rate': 0.9, 'n_estimators': 64}
# [39/40] {'learning_rate': 0.9, 'n_estimators': 100}
# [40/40] {'learning_rate': 0.9, 'n_estimators': 200}
# C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# Results for GB:
#
#
# RMSE: 0.521400472745441
# NRMSE: 0.1950516976018451
# NDEI: 0.18501956988772889
# MAE: 0.3205053131519658
# MAPE: 0.2713543893105832
# Rules: -
#
# {'learning_rate': 0.1, 'n_estimators': 64}

# %% [markdown]
# ### XGBoost

# %%
Model_Name = "XGBoost"

# Define Grid Search parameters
parameters = {'n_estimators':[250, 500], 'min_child_weight':[2,5], 
              'gamma':[i/10.0 for i in range(3,6)], 'max_depth': [2, 3, 4, 6, 7], 
              'eval_metric':['rmse'],'eta':[i/10.0 for i in range(3,6)]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )


    # Optimize parameters
    XGBoost = XGBRegressor(**param)
    XGBoost.fit(X_train,y_train)
    # Make predictions
    y_pred = XGBoost.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_XGBoost_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
XGBoost = XGBRegressor(**best_XGBoost_params)
XGBoost.fit(new_X_train,new_y_train)
# Make predictions
y_pred = XGBoost.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)
   
XGBoost_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

print(f'\n{best_XGBoost_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_XGBoost_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [2/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [3/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [4/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [5/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [6/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [7/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [8/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [9/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [10/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [11/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [12/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [13/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [14/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [15/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [16/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [17/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [18/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [19/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [20/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [21/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [22/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [23/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [24/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [25/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [26/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [27/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [28/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [29/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [30/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [31/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [32/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [33/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [34/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [35/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [36/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [37/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [38/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [39/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [40/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [41/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [42/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [43/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [44/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [45/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [46/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [47/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [48/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [49/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [50/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [51/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [52/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [53/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [54/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [55/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [56/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [57/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [58/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [59/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [60/180] {'eta': 0.3, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [61/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [62/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [63/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [64/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [65/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [66/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [67/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [68/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [69/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [70/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [71/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [72/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [73/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [74/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [75/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [76/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [77/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [78/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [79/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [80/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [81/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [82/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [83/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [84/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [85/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [86/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [87/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [88/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [89/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [90/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [91/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [92/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [93/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [94/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [95/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [96/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [97/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [98/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [99/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [100/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [101/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [102/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [103/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [104/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [105/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [106/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [107/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [108/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [109/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [110/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [111/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [112/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [113/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [114/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [115/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [116/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [117/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [118/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [119/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [120/180] {'eta': 0.4, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [121/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [122/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [123/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [124/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [125/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [126/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [127/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [128/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [129/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [130/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [131/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [132/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [133/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [134/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [135/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [136/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [137/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [138/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [139/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [140/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.3, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [141/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [142/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [143/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [144/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [145/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [146/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [147/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [148/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [149/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [150/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [151/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [152/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [153/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [154/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [155/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [156/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [157/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [158/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [159/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [160/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
# [161/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}
# [162/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 500}
# [163/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 250}
# [164/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 500}
# [165/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 250}
# [166/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 500}
# [167/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 250}
# [168/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# [169/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 250}
# [170/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 500}
# [171/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
# [172/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 500}
# [173/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 250}
# [174/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 500}
# [175/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
# [176/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500}
# [177/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 250}
# [178/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 500}
# [179/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 250}
# [180/180] {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.5, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 500}
#
# Results for XGBoost:
#
#
# RMSE: 1.1530771524225816
# NRMSE: 0.5106755331326192
# NDEI: 0.40917078127152245
# MAE: 0.8403136739199033
# MAPE: 0.9419297109565565
# Rules: -
#
# {'eta': 0.5, 'eval_metric': 'rmse', 'gamma': 0.4, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 250}

# %% [markdown]
# ### LGBM

# %%
Model_Name = "LGBM"

# Define Grid Search parameters
parameters = {'learning_rate':[0.01, 0.05, 0.1, 0.5, 0.9],'verbosity':[-1]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )
    
    # Optimize parameters
    LGBM = LGBMRegressor(**param)
    LGBM.fit(X_train,y_train.ravel())
    # Make predictions
    y_pred = LGBM.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_LGBM_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
LGBM = LGBMRegressor(**best_LGBM_params)
LGBM.fit(new_X_train,new_y_train)
# Make predictions
y_pred = LGBM.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)
   
LGBM_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

print(f'\n{best_LGBM_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_LGBM_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/5] {'learning_rate': 0.01, 'verbosity': -1}
# [2/5] {'learning_rate': 0.05, 'verbosity': -1}
# [3/5] {'learning_rate': 0.1, 'verbosity': -1}
# [4/5] {'learning_rate': 0.5, 'verbosity': -1}
# [5/5] {'learning_rate': 0.9, 'verbosity': -1}
# C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Results for LGBM:
#
#
# RMSE: 0.4121925739461144
# NRMSE: 0.14749305392169962
# NDEI: 0.1462670187866507
# MAE: 0.20081349887508326
# MAPE: 0.10515815858575372
# Rules: -
#
# {'learning_rate': 0.05, 'verbosity': -1}

# %% [markdown]
# ## Deep Learning

# %%
X_train_DL = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val_DL = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test_DL = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
Model_Name = "MLP"

# Define the function to create models for the optimization method
def build_model(n_hidden=1, n_neurons=30, activation = "relu", learning_rate=3e-3, input_shape=[4]):
    model = Sequential()
    model.add(InputLayer(input_shape=input_shape))
    for layer in range(n_hidden):
        model.add(Dense(n_neurons, activation=activation))
    model.add(Dense(1))
    optimizer = SGD(learning_rate=learning_rate)
    model.compile(loss="mse", optimizer=optimizer)
    return model

# Set the parameters for the network
best_MLP_parameters = {'n_hidden':2, 'n_neurons':77, 'activation':"relu", 'learning_rate': 0.145, 'input_shape': X_train_DL.shape[1]}

# Checkpoint for early stopping
checkpoint_cb = ModelCheckpoint(f'RandomSearchResults/{Model_Name}.keras', save_best_only=True)
early_stopping_cb = EarlyStopping(patience=20,restore_best_weights=True)

# Define the model
model = build_model(**best_MLP_parameters)

# Fit the model
history = model.fit(X_train_DL, y_train, epochs = 1000, validation_data=(X_val_DL, y_val), callbacks=[checkpoint_cb, early_stopping_cb])

# Make predictions
y_pred = model.predict(X_test_DL)
# Out:
# c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [202], in <cell line: 22>()
#      19 early_stopping_cb = EarlyStopping(patience=20,restore_best_weights=True)
#      21 # Define the model
# ---> 22 model = build_model(**best_MLP_parameters)
#      24 # Fit the model
#      25 history = model.fit(X_train_DL, y_train, epochs = 1000, validation_data=(X_val_DL, y_val), callbacks=[checkpoint_cb, early_stopping_cb])
#
# Input In [202], in build_model(n_hidden, n_neurons, activation, learning_rate, input_shape)
#       4 def build_model(n_hidden=1, n_neurons=30, activation = "relu", learning_rate=3e-3, input_shape=[4]):
#       5     model = Sequential()
# ----> 6     model.add(InputLayer(input_shape=input_shape))
#       7     for layer in range(n_hidden):
#       8         model.add(Dense(n_neurons, activation=activation))
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\input_layer.py:47, in InputLayer.__init__(self, shape, batch_size, dtype, sparse, batch_shape, input_tensor, optional, name, **kwargs)
#      44     raise ValueError("You must pass a `shape` argument.")
#      46 if shape is not None:
# ---> 47     shape = backend.standardize_shape(shape)
#      48     batch_shape = (batch_size,) + shape
#      49 self._batch_shape = backend.standardize_shape(batch_shape)
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\common\variables.py:515, in standardize_shape(shape)
#     513     raise ValueError("Undefined shapes are not supported.")
#     514 if not hasattr(shape, "__iter__"):
# --> 515     raise ValueError(f"Cannot convert '{shape}' to a shape.")
#     516 if config.backend() == "tensorflow":
#     517     if isinstance(shape, tf.TensorShape):
#     518         # `tf.TensorShape` may contain `Dimension` objects.
#     519         # We need to convert the items in it to either int or `None`
#
# ValueError: Cannot convert '12' to a shape.

# %%
# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred.ravel()

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
Rules = "-"
print("Rules:", Rules)
   
MLP_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_MLP_parameters]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# %% [markdown]
# ## evolving Fuzzy Systems

# %% [markdown]
# ### eTS

# %%
Model_Name = "eTS"

# Define Grid Search parameters
parameters = {'InitialOmega': [50, 100, 250, 500, 750, 1000, 10000], 'r': [0.1, 0.3, 0.5, 0.7, 0.9, 1., 5, 10, 50]}


grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = eTS(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_eTS_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = eTS(**best_eTS_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])

   
eTS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_eTS_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_eTS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/63] {'InitialOmega': 50, 'r': 0.1}
# [2/63] {'InitialOmega': 50, 'r': 0.3}
# [3/63] {'InitialOmega': 50, 'r': 0.5}
# [4/63] {'InitialOmega': 50, 'r': 0.7}
# [5/63] {'InitialOmega': 50, 'r': 0.9}
# [6/63] {'InitialOmega': 50, 'r': 1.0}
# [7/63] {'InitialOmega': 50, 'r': 5}
# [8/63] {'InitialOmega': 50, 'r': 10}
# [9/63] {'InitialOmega': 50, 'r': 50}
# [10/63] {'InitialOmega': 100, 'r': 0.1}
# [11/63] {'InitialOmega': 100, 'r': 0.3}
# [12/63] {'InitialOmega': 100, 'r': 0.5}
# [13/63] {'InitialOmega': 100, 'r': 0.7}
# [14/63] {'InitialOmega': 100, 'r': 0.9}
# [15/63] {'InitialOmega': 100, 'r': 1.0}
# [16/63] {'InitialOmega': 100, 'r': 5}
# [17/63] {'InitialOmega': 100, 'r': 10}
# [18/63] {'InitialOmega': 100, 'r': 50}
# [19/63] {'InitialOmega': 250, 'r': 0.1}
# [20/63] {'InitialOmega': 250, 'r': 0.3}
# [21/63] {'InitialOmega': 250, 'r': 0.5}
# [22/63] {'InitialOmega': 250, 'r': 0.7}
# [23/63] {'InitialOmega': 250, 'r': 0.9}
# [24/63] {'InitialOmega': 250, 'r': 1.0}
# [25/63] {'InitialOmega': 250, 'r': 5}
# [26/63] {'InitialOmega': 250, 'r': 10}
# [27/63] {'InitialOmega': 250, 'r': 50}
# [28/63] {'InitialOmega': 500, 'r': 0.1}
# [29/63] {'InitialOmega': 500, 'r': 0.3}
# [30/63] {'InitialOmega': 500, 'r': 0.5}
# [31/63] {'InitialOmega': 500, 'r': 0.7}
# [32/63] {'InitialOmega': 500, 'r': 0.9}
# [33/63] {'InitialOmega': 500, 'r': 1.0}
# [34/63] {'InitialOmega': 500, 'r': 5}
# [35/63] {'InitialOmega': 500, 'r': 10}
# [36/63] {'InitialOmega': 500, 'r': 50}
# [37/63] {'InitialOmega': 750, 'r': 0.1}
# [38/63] {'InitialOmega': 750, 'r': 0.3}
# [39/63] {'InitialOmega': 750, 'r': 0.5}
# [40/63] {'InitialOmega': 750, 'r': 0.7}
# [41/63] {'InitialOmega': 750, 'r': 0.9}
# [42/63] {'InitialOmega': 750, 'r': 1.0}
# [43/63] {'InitialOmega': 750, 'r': 5}
# [44/63] {'InitialOmega': 750, 'r': 10}
# [45/63] {'InitialOmega': 750, 'r': 50}
# [46/63] {'InitialOmega': 1000, 'r': 0.1}
# [47/63] {'InitialOmega': 1000, 'r': 0.3}
# [48/63] {'InitialOmega': 1000, 'r': 0.5}
# [49/63] {'InitialOmega': 1000, 'r': 0.7}
# [50/63] {'InitialOmega': 1000, 'r': 0.9}
# [51/63] {'InitialOmega': 1000, 'r': 1.0}
# [52/63] {'InitialOmega': 1000, 'r': 5}
# [53/63] {'InitialOmega': 1000, 'r': 10}
# [54/63] {'InitialOmega': 1000, 'r': 50}
# [55/63] {'InitialOmega': 10000, 'r': 0.1}
# [56/63] {'InitialOmega': 10000, 'r': 0.3}
# [57/63] {'InitialOmega': 10000, 'r': 0.5}
# [58/63] {'InitialOmega': 10000, 'r': 0.7}
# [59/63] {'InitialOmega': 10000, 'r': 0.9}
# [60/63] {'InitialOmega': 10000, 'r': 1.0}
# [61/63] {'InitialOmega': 10000, 'r': 5}
# [62/63] {'InitialOmega': 10000, 'r': 10}
# [63/63] {'InitialOmega': 10000, 'r': 50}
#
# Results for eTS:
#
#
# RMSE: 0.7737610417836223
# NRMSE: 0.290096008974898
# NDEI: 0.27457001408700504
# MAE: 0.49910098451140456
# MAPE: 0.32139455919384213
# Rules: 4
#
# {'InitialOmega': 50, 'r': 5}

# %% [markdown]
# ### Simpl_eTS

# %%
Model_Name = "Simpl_eTS"

# Define Grid Search parameters
parameters = {'InitialOmega': [50, 250, 500, 750, 1000], 'r': [0.1, 0.3, 0.5, 0.7]}


grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = Simpl_eTS(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_Simpl_eTS_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = Simpl_eTS(**best_Simpl_eTS_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
Simpl_eTS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_Simpl_eTS_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_Simpl_eTS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/20] {'InitialOmega': 50, 'r': 0.1}
# [2/20] {'InitialOmega': 50, 'r': 0.3}
# [3/20] {'InitialOmega': 50, 'r': 0.5}
# [4/20] {'InitialOmega': 50, 'r': 0.7}
# [5/20] {'InitialOmega': 250, 'r': 0.1}
# [6/20] {'InitialOmega': 250, 'r': 0.3}
# [7/20] {'InitialOmega': 250, 'r': 0.5}
# [8/20] {'InitialOmega': 250, 'r': 0.7}
# [9/20] {'InitialOmega': 500, 'r': 0.1}
# [10/20] {'InitialOmega': 500, 'r': 0.3}
# [11/20] {'InitialOmega': 500, 'r': 0.5}
# [12/20] {'InitialOmega': 500, 'r': 0.7}
# [13/20] {'InitialOmega': 750, 'r': 0.1}
# [14/20] {'InitialOmega': 750, 'r': 0.3}
# [15/20] {'InitialOmega': 750, 'r': 0.5}
# [16/20] {'InitialOmega': 750, 'r': 0.7}
# [17/20] {'InitialOmega': 1000, 'r': 0.1}
# [18/20] {'InitialOmega': 1000, 'r': 0.3}
# [19/20] {'InitialOmega': 1000, 'r': 0.5}
# [20/20] {'InitialOmega': 1000, 'r': 0.7}
#
# Results for Simpl_eTS:
#
#
# RMSE: 0.6563461460089548
# NRMSE: 0.24206215361231012
# NDEI: 0.23290520047405755
# MAE: 0.36698905497861184
# MAPE: 0.19033928962355234
# Rules: 5
#
# {'InitialOmega': 50, 'r': 0.7}

# %% [markdown]
# ### exTS

# %%
Model_Name = "exTS"

# Define Grid Search parameters
parameters = {'InitialOmega': [50, 250, 500, 750, 1000], 'mu_threshold': [0.1, 0.3, 0.5, 0.7]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = exTS(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_exTS_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = exTS(**best_exTS_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
exTS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_exTS_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_exTS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/20] {'InitialOmega': 50, 'mu_threshold': 0.1}
# [2/20] {'InitialOmega': 50, 'mu_threshold': 0.3}
# [3/20] {'InitialOmega': 50, 'mu_threshold': 0.5}
# [4/20] {'InitialOmega': 50, 'mu_threshold': 0.7}
# [5/20] {'InitialOmega': 250, 'mu_threshold': 0.1}
# [6/20] {'InitialOmega': 250, 'mu_threshold': 0.3}
# [7/20] {'InitialOmega': 250, 'mu_threshold': 0.5}
# [8/20] {'InitialOmega': 250, 'mu_threshold': 0.7}
# [9/20] {'InitialOmega': 500, 'mu_threshold': 0.1}
# [10/20] {'InitialOmega': 500, 'mu_threshold': 0.3}
# [11/20] {'InitialOmega': 500, 'mu_threshold': 0.5}
# [12/20] {'InitialOmega': 500, 'mu_threshold': 0.7}
# [13/20] {'InitialOmega': 750, 'mu_threshold': 0.1}
# [14/20] {'InitialOmega': 750, 'mu_threshold': 0.3}
# [15/20] {'InitialOmega': 750, 'mu_threshold': 0.5}
# [16/20] {'InitialOmega': 750, 'mu_threshold': 0.7}
# [17/20] {'InitialOmega': 1000, 'mu_threshold': 0.1}
# [18/20] {'InitialOmega': 1000, 'mu_threshold': 0.3}
# [19/20] {'InitialOmega': 1000, 'mu_threshold': 0.5}
# [20/20] {'InitialOmega': 1000, 'mu_threshold': 0.7}
#
# Results for exTS:
#
#
# RMSE: 2.995090686143244
# NRMSE: 0.9311061099467525
# NDEI: 1.062811446271001
# MAE: 1.697358750226043
# MAPE: 1.45659533954571
# Rules: 16
#
# {'InitialOmega': 50, 'mu_threshold': 0.1}

# %% [markdown]
# ### ePL

# %%
Model_Name = "ePL"

# Define Grid Search parameters
parameters = {'alpha': [0.001, 0.01, 0.1, 0.5, 0.9], 'beta': [0.001, 0.005, 0.01, 0.1, 0.2], 'lambda1': [0.001, 0.01, 0.1], 's': [100, 10000], 'r': [0.1, 0.25, 0.5, 0.75]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = ePL(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_ePL_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = ePL(**best_ePL_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
ePL_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_ePL_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_ePL_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/600] {'alpha': 0.001, 'beta': 0.001, 'lambda1': 0.001, 'r': 0.1, 's': 100}
# [2/600] {'alpha': 0.001, 'beta': 0.001, 'lambda1': 0.001, 'r': 0.1, 's': 10000}
# [3/600] {'alpha': 0.001, 'beta': 0.001, 'lambda1': 0.001, 'r': 0.25, 's': 100}
# [4/600] {'alpha': 0.001, 'beta': 0.001, 'lambda1': 0.001, 'r': 0.25, 's': 10000}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [36], in <cell line: 8>()
#      12 # Optimize parameters
#      13 model = ePL(**param)
# ---> 14 model.fit(X_train,y_train)
#      15 # Make predictions
#      16 y_pred = model.predict(X_val)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL.py:61, in ePL.fit(self, X, y)
#      59     self.Rule_Update(x, y[k], MaxIndexCompatibility)
#      60 if self.parameters.shape[0] > 1:
# ---> 61     self.Similarity_Index()
#      62 # Compute the number of rules at the current iteration
#      63 self.rules.append(self.parameters.shape[0])
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL.py:163, in ePL.Similarity_Index(self)
#     161 for j in range(i + 1, self.parameters.shape[0]):
#     162     vi, vj = self.parameters.iloc[i,0], self.parameters.iloc[j,0]
# --> 163     compat_ij = (1 - ((np.linalg.norm(vi - vj))))
#     164     if compat_ij >= self.hyperparameters.loc[0, 'lambda1']:
#     165         self.parameters.at[self.parameters.index[j], 'Center'] = ( (self.parameters.loc[self.parameters.index[i], 'Center'] + self.parameters.loc[self.parameters.index[j], 'Center']) / 2)
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\linalg\linalg.py:2511, in norm(x, ord, axis, keepdims)
#    2509     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2510 else:
# -> 2511     sqnorm = x.dot(x)
#    2512 ret = sqrt(sqnorm)
#    2513 if keepdims:
#
# KeyboardInterrupt:

# %% [markdown]
# ### eMG

# %%
Model_Name = "eMG"

# Define Grid Search parameters
parameters = {'alpha': [0.001, 0.01], 'lambda1': [0.1, 0.5], 'w': [10, 50], 'sigma': [0.001, 0.003], 'omega': [10**4]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = eMG(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_eMG_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = eMG(**best_eMG_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
eMG_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_eMG_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_eMG_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/16] {'alpha': 0.001, 'lambda1': 0.1, 'omega': 10000, 'sigma': 0.001, 'w': 10}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 8>()
#      12 # Optimize parameters
#      13 model = eMG(**param)
# ---> 14 model.fit(X_train,y_train)
#      15 # Make predictions
#      16 y_pred = model.predict(X_val)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\eMG.py:84, in eMG.fit(self, X, y)
#      82         self.Update_Consequent_Parameters(xk, y[k], i)
#      83     if self.parameters.shape[0] > 1:
# ---> 84         self.Merging_Rules(X[k,], center)
#      85     self.rules.append(self.parameters.shape[0])
#      86 return self.OutputTrainingPhase, self.rules
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\eMG.py:159, in eMG.Merging_Rules(self, x, MaxIndexCompatibility)
#     157 if MaxIndexCompatibility != i:
#     158     dist1 = self.M_Distance(self.parameters.loc[MaxIndexCompatibility, 'Center'], i)
# --> 159     dist2 = self.M_Distance(self.parameters.loc[i, 'Center'], MaxIndexCompatibility)
#     160     if dist1 < self.Tp or dist2 < self.Tp:
#     161         self.parameters.at[MaxIndexCompatibility, 'Center'] = np.mean(np.array([self.parameters.loc[i, 'Center'], self.parameters.loc[MaxIndexCompatibility, 'Center']]), axis=0)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\eMG.py:122, in eMG.M_Distance(self, x, i)
#     121 def M_Distance(self, x, i):
# --> 122     dist = mahalanobis_distance.mahalanobis(x, self.parameters.loc[i, 'Center'], np.linalg.inv(self.parameters.loc[i, 'Sigma']))
#     123     return dist
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\mahalanobis_distance.py:124, in mahalanobis(u, v, VI)
#     122 VI = np.atleast_2d(VI)
#     123 delta = u - v
# --> 124 m = np.dot(np.dot(delta, VI), delta)
#     125 return m
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### ePL+

# %%
Model_Name = "ePL_plus"

# Define Grid Search parameters
parameters = {'alpha': [0.001, 0.01, 0.1], 'beta': [0.01, 0.1, 0.25], 'lambda1': [0.25, 0.5, 0.75], 'omega': [100, 10000], 'sigma': [0.1, 0.25, 0.5], 'e_Utility': [0.03, 0.05], 'pi': [0.3, 0.5]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = ePL_plus(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_ePL_plus_params = param

# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = ePL_plus(**best_ePL_plus_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
ePL_plus_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

print(f'\n{best_ePL_plus_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_ePL_plus_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

# %% [markdown]
# ### ePL-KRLS-DISCO

# %%
Model_Name = "ePL_KRLS_DISCO"

# Define Grid Search parameters
parameters = {'alpha': [0.05, 0.1], 'beta': [0.01, 0.1, 0.25], 'lambda1': [0.0000001, 0.001], 'sigma': [0.5, 1, 10, 50], 'e_utility': [0.03, 0.05]}
grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = ePL_KRLS_DISCO(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_ePL_KRLS_DISCO_params = param
        
# Optimized parameters

new_X_train, new_y_train = X.values[:index_val], y[:index_val]
model = ePL_KRLS_DISCO(**best_ePL_KRLS_DISCO_params)
OutputTraining, Rules = model.fit(new_X_train,new_y_train)
# Make predictions
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Number of rules
print("Rules:", Rules[-1])
   
ePL_KRLS_DISCO_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules[-1]}'

#print(f'\n{best_ePL_KRLS_DISCO_params}')

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules[-1], best_ePL_KRLS_DISCO_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")
# Out:
# [1/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [2/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760416371194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [3/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.0716369876805665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [4/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289888862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [5/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [6/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760416371194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [7/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.0716369876805665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [8/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289888862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [9/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [10/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760416371194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [11/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.0716369876805665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [12/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289888862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [13/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [14/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760416371194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [15/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.0716369876805665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [16/96] {'alpha': 0.05, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289888862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [17/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [18/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760327316199' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [19/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636986782949' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [20/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289870909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [21/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [22/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760327316199' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [23/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636986782949' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [24/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289870909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [25/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [26/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760327316199' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [27/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636986782949' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [28/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289870909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [29/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [30/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760327316199' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [31/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636986782949' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [32/96] {'alpha': 0.05, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289870909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [33/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [34/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760178888376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [35/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636985286891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [36/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289840985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [37/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [38/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760178888376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [39/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636985286891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [40/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289840985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [41/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [42/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760178888376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [43/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636985286891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [44/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289840985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [45/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [46/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7127760178888376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [47/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636985286891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [48/96] {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35545289840985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [49/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [50/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520213846844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [51/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584188989521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [52/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35544233837227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [53/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [54/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520213846844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [55/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584188989521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [56/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35544233837227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [57/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [58/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520213846844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [59/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584188989521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [60/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35544233837227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [61/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [62/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520213846844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [63/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584188989521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [64/96] {'alpha': 0.1, 'beta': 0.01, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.35544233837227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [65/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [66/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520055117959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [67/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584187390798' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [68/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442338052505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [69/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [70/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520055117959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [71/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584187390798' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [72/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442338052505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [73/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [74/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520055117959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [75/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584187390798' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [76/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442338052505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [77/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [78/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122520055117959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [79/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584187390798' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [80/96] {'alpha': 0.1, 'beta': 0.1, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442338052505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [81/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 0.5}
# [82/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122519790565536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [83/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584184726219' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [84/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442337519555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [85/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 0.5}
# [86/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122519790565536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [87/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584184726219' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [88/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.03, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442337519555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [89/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 0.5}
# [90/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122519790565536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [91/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584184726219' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [92/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 1e-07, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442337519555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [93/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 0.5}
# [94/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.7122519790565536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [95/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071584184726219' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# [96/96] {'alpha': 0.1, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 50}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.355442337519555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\ePL_KRLS_DISCO.py:158: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.071636985286891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.parameters.at[i, 'nu'] = math.sqrt((self.parameters.loc[i, 'nu'])**2 + (((np.linalg.norm(x - self.parameters.loc[i, 'Center']))**2 - (self.parameters.loc[i, 'nu'])**2)/self.parameters.loc[i, 'NumObservations']) + ((self.parameters.loc[i, 'NumObservations'] - 1) * ((np.linalg.norm(self.parameters.loc[i, 'Center'] - self.parameters.loc[i, 'OldCenter']))**2))/self.parameters.loc[i, 'NumObservations'])
# Results for ePL_KRLS_DISCO:
#
#
# RMSE: 1.4952807109239588
# NRMSE: 0.5982632110140199
# NDEI: 0.5306021157591813
# MAE: 1.1103578038522137
# MAPE: 0.9993082047800629
# Rules: 20

# %%
best_ePL_KRLS_DISCO_params
# Out:
# {'alpha': 0.05, 'beta': 0.25, 'e_utility': 0.05, 'lambda1': 0.001, 'sigma': 10}

# %% [markdown]
# ## Proposed Models (Kaike)

# %% [markdown]
# ### NMFIS

# %%
Model_Name = "NMFIS"

# Set hyperparameters range
parameters = {'n_clusters':range(1,20)}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = NMFIS(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_NMFIS_params = param

# Initialize the model
model = NMFIS(**best_NMFIS_params)
new_X_train, new_y_train = X.values[:index_val], y[:index_val]

# Train the model
OutputTraining = model.fit(new_X_train, new_y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.parameters.shape[0]
print("Rules:", Rules)



NMFIS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_NMFIS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")

# %% [markdown]
# ### NTSK-RLS

# %%
Model_Name = "NTSK-RLS"

# Set hyperparameters range
parameters = {'n_clusters':[1], 'lambda1':[0.95,0.96,0.97,0.98,0.99], 'RLS_option':[1]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = NTSK(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_NTSK_RLS_params = param

# Initialize the model
model = NTSK(**best_NTSK_RLS_params)
new_X_train, new_y_train = X.values[:index_val], y[:index_val]

# Train the model
OutputTraining = model.fit(new_X_train, new_y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.parameters.shape[0]
print("Rules:", Rules)  

NTSK_RLS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'



# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_NTSK_RLS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")
# Out:
# [1/5] {'RLS_option': 1, 'lambda1': 0.95, 'n_clusters': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:102: RuntimeWarning: overflow encountered in square
#   self.ResidualTrainingPhase = np.append(self.ResidualTrainingPhase,(Output - y[k])**2)
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: overflow encountered in multiply
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: invalid value encountered in multiply
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: invalid value encountered in add
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:95: RuntimeWarning: invalid value encountered in matmul
#   Output =  xe.T @ self.Theta
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: invalid value encountered in matmul
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 9>()
#      17 y_pred = model.predict(X_val)
#      20 # Calculating the error metrics
#      21 # Compute the Root Mean Square Error
# ---> 22 RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
#      24 if RMSE < lower_rmse:
#      25     lower_rmse = RMSE
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:497, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     492     if not squared:
#     493         return root_mean_squared_error(
#     494             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     495         )
# --> 497 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     498     y_true, y_pred, multioutput
#     499 )
#     500 check_consistent_length(y_true, y_pred, sample_weight)
#     501 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     102 check_consistent_length(y_true, y_pred)
#     103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#     107     y_true = y_true.reshape((-1, 1))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %% [markdown]
# ### NTSK-wRLS

# %%
Model_Name = "NTSK-wRLS"

# Set hyperparameters range
# parameters = {'n_clusters':range(1,20), 'RLS_option':[2]}
parameters = {'n_clusters':range(1,2), 'RLS_option':[2]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}")

    # Optimize parameters
    model = NTSK(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_NTSK_wRLS_params = param

# Initialize the model
model = NTSK(**best_NTSK_wRLS_params)
# Train the model
new_X_train, new_y_train = X.values[:index_val], y[:index_val]
OutputTraining = model.fit(new_X_train, new_y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.parameters.shape[0]
print("Rules:", Rules)  



NTSK_wRLS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_NTSK_wRLS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")
# Out:
# [1/1] {'RLS_option': 2, 'n_clusters': 1}
#
# Results for NTSK-wRLS:
#
#
# RMSE: 0.6450422809739007
# NRMSE: 0.2335581743594338
# NDEI: 0.22889401069541743
# MAE: 0.3594328388108757
# MAPE: 0.1907822388548914
# Rules: 1
# An error occurred while saving the model parameters: Cannot save file into a non-existent directory: 'Model Summary'

# %% [markdown]
# ### GEN-NMFIS

# %%
Model_Name = "GEN-NMFIS"

# Set hyperparameters range
# parameters = {'n_clusters':range(1,20)}
parameters = {'n_clusters':range(1,2)}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = GEN_NMFIS(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_GEN_NMFIS_params = param

# Initialize the model
model = GEN_NMFIS(**best_GEN_NMFIS_params)
# Train the model
new_X_train, new_y_train = X.values[:index_val], y[:index_val]
OutputTraining = model.fit(new_X_train, new_y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.model.parameters.shape[0]
print("Rules:", Rules)


GEN_NMFIS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_GEN_NMFIS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")
# Out:
# [1/1] {'n_clusters': 1}
#
# Results for GEN-NMFIS:
#
#
# RMSE: 3.6362266576105142
# NRMSE: 4088060731724220.0
# NDEI: 1.2903192984519094
# MAE: 3.0843174581155344
# MAPE: 2.942418142249831
# Rules: 1
# An error occurred while saving the model parameters: Cannot save file into a non-existent directory: 'Model Summary'

# %% [markdown]
# ### GEN-NTSK-RLS

# %%
Model_Name = "GEN-NTSK-RLS"

# Set hyperparameters range
# parameters = {'n_clusters':[1], 'lambda1':[0.95,0.96,0.97,0.98,0.99], 'RLS_option':[1]}
parameters = {'n_clusters':[1], 'lambda1':[0.95], 'RLS_option':[1]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = GEN_NTSK(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_GEN_NTSK_RLS_params = param

# Initialize the model
model = GEN_NTSK(**best_GEN_NTSK_RLS_params)
# Train the model
new_X_train, new_y_train = X.values[:index_val], y[:index_val]
OutputTraining = model.fit(new_X_train, new_y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.model.parameters.shape[0]
print("Rules:", Rules)  

GEN_NTSK_RLS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_GEN_NTSK_RLS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")
# Out:
# [1/1] {'RLS_option': 1, 'lambda1': 0.95, 'n_clusters': 1}
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:102: RuntimeWarning: overflow encountered in square
#   self.ResidualTrainingPhase = np.append(self.ResidualTrainingPhase,(Output - y[k])**2)
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: overflow encountered in multiply
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:95: RuntimeWarning: invalid value encountered in matmul
#   Output =  xe.T @ self.Theta
# d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:188: RuntimeWarning: invalid value encountered in matmul
#   self.Theta = self.Theta + ( self.P @ xe ) * (y - xe.T @ self.Theta )
# Input contains NaN.
# Traceback (most recent call last):
#   File "c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py", line 1708, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py", line 172, in genetic_algorithm
#     RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py", line 497, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py", line 104, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 1049, in check_array
#     _assert_all_finite(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 126, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 175, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# Input contains NaN.
# Traceback (most recent call last):
#   File "c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py", line 1914, in run
#     self.last_generation_fitness = self.cal_pop_fitness()
#   File "c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py", line 1871, in cal_pop_fitness
#     raise ex
#   File "c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py", line 1708, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py", line 172, in genetic_algorithm
#     RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py", line 497, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py", line 104, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 1049, in check_array
#     _assert_all_finite(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 126, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\thevh\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 175, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [230], in <cell line: 10>()
#      14 # Optimize parameters
#      15 model = GEN_NTSK(**param)
# ---> 16 model.fit(X_train,y_train)
#      17 # Make predictions
#      18 y_pred = model.predict(X_val)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py:87, in GEN_NTSK.fit(self, X, y)
#      75 ga_instance = pygad.GA(num_generations=self.num_generations,
#      76                        num_parents_mating=self.num_parents_mating,
#      77                        sol_per_pop=self.sol_per_pop,
#    (...)
#      83                        suppress_warnings=True,
#      84                        gene_type=int)
#      86 # Running the GA to optimize the parameters of the function.
# ---> 87 ga_instance.run()
#      89 # Returning the details of the best solution.
#      90 self.solution, solution_fitness, solution_idx = ga_instance.best_solution(ga_instance.last_generation_fitness)
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:2095, in GA.run(self)
#    2093 self.logger.exception(ex)
#    2094 # sys.exit(-1)
# -> 2095 raise ex
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:1914, in GA.run(self)
#    1911     generation_last_idx = self.num_generations
#    1913 # Measuring the fitness of each chromosome in the population. Save the fitness in the last_generation_fitness attribute.
# -> 1914 self.last_generation_fitness = self.cal_pop_fitness()
#    1916 best_solution, best_solution_fitness, best_match_idx = self.best_solution(pop_fitness=self.last_generation_fitness)
#    1918 # Appending the best solution in the initial population to the best_solutions list.
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:1871, in GA.cal_pop_fitness(self)
#    1869     self.logger.exception(ex)
#    1870     # sys.exit(-1)
# -> 1871     raise ex
#    1872 return pop_fitness
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:1708, in GA.cal_pop_fitness(self)
#    1705 else:
#    1706     # Check if batch processing is used. If not, then calculate this missing fitness value.
#    1707     if self.fitness_batch_size in [1, None]:
# -> 1708         fitness = self.fitness_func(self, sol, sol_idx)
#    1709         if type(fitness) in GA.supported_int_float_types:
#    1710             # The fitness function returns a single numeric value.
#    1711             # This is a single-objective optimization problem.
#    1712             pass
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py:172, in GEN_NTSK.genetic_algorithm(self, ga_instance, selected_cols, selected_cols_idx)
#     168 y_pred = self.model.predict(X_val)
#     170 # Calculating the error metrics
#     171 # Compute the Root Mean Square Error
# --> 172 RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
#     173 # Compute the Normalized Root Mean Square Error
#     174 NRMSE = RegressionMetric(y_val, y_pred).normalized_root_mean_square_error()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:497, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     492     if not squared:
#     493         return root_mean_squared_error(
#     494             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     495         )
# --> 497 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     498     y_true, y_pred, multioutput
#     499 )
#     500 check_consistent_length(y_true, y_pred, sample_weight)
#     501 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     102 check_consistent_length(y_true, y_pred)
#     103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#     107     y_true = y_true.reshape((-1, 1))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %% [markdown]
# ### GEN-NTSK-wRLS

# %%
Model_Name = "GEN-NTSK-wRLS"

# Set hyperparameters range
# parameters = {'n_clusters':range(1,20), 'RLS_option':[2]}
parameters = {'n_clusters':range(1,2), 'RLS_option':[2]}

grid = ParameterGrid(parameters)

lower_rmse = np.inf
for i,param in enumerate(grid):
    
    print(f"[{i+1}/{len(grid)}] {param}" )

    # Optimize parameters
    model = GEN_NTSK(**param)
    model.fit(X_train,y_train)
    # Make predictions
    y_pred = model.predict(X_val)
    
    
    # Calculating the error metrics
    # Compute the Root Mean Square Error
    RMSE = math.sqrt(mean_squared_error(y_val, y_pred))
    
    if RMSE < lower_rmse:
        lower_rmse = RMSE
        best_GEN_NTSK_wRLS_params = param

# Initialize the model
model = GEN_NTSK(**best_GEN_NTSK_wRLS_params)
# Train the model
new_X_train, new_y_train = X.values[:index_val], y[:index_val]
OutputTraining = model.fit(X_train, y_train)
# Test the model
y_pred = model.predict(X_test)

# Save predictions to dataframe
y_pred = scaler_y.inverse_transform(y_pred.reshape(1, -1)).reshape(-1,1)
predictions[f'{Model_Name}'] = y_pred

# Model name
print(f'\nResults for {Model_Name}: \n')

# Calculating the error metrics
# Compute the Root Mean Square Error
RMSE = math.sqrt(mean_squared_error(y_test, y_pred))
print("\nRMSE:", RMSE)
# Compute the Normalized Root Mean Square Error
NRMSE = RegressionMetric(y_test, y_pred).normalized_root_mean_square_error()
print("NRMSE:", NRMSE)
# Compute the Non-Dimensional Error Index
NDEI= RMSE/st.stdev(np.asfarray(y_test.flatten()))
print("NDEI:", NDEI)
# Compute the Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
print("MAE:", MAE)
# Compute the Mean Absolute Percentage Error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", MAPE)
# Compute the number of final rules
Rules = model.model.parameters.shape[0]
print("Rules:", Rules)  


GEN_NTSK_wRLS_ = f'{Model_Name} & {NRMSE:.2f} & {NDEI:.2f} & {MAPE:.2f} & {Rules}'

# Store results to dataframe
newrow = pd.DataFrame([[Model_Name, NRMSE, NDEI, MAPE, Rules, best_GEN_NTSK_wRLS_params]], columns=columns)
results = pd.concat([results, newrow], ignore_index=True)

# salvando em planilha
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

results.to_excel(f"../Relatórios/results_{timestamp}.xlsx")
predictions.to_excel(f"../Relatórios/predictions_{timestamp}.xlsx")

try:
    # Save the model to excel
    model.parameters.to_excel(f'../Relatórios/Model Summary/{Model_Name}_parameters.xlsx')
except Exception as e:
    print(f"An error occurred while saving the model parameters: {e}")
# Out:
# [1/1] {'RLS_option': 2, 'n_clusters': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [229], in <cell line: 10>()
#      14 # Optimize parameters
#      15 model = GEN_NTSK(**param)
# ---> 16 model.fit(X_train,y_train)
#      17 # Make predictions
#      18 y_pred = model.predict(X_val)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py:87, in GEN_NTSK.fit(self, X, y)
#      75 ga_instance = pygad.GA(num_generations=self.num_generations,
#      76                        num_parents_mating=self.num_parents_mating,
#      77                        sol_per_pop=self.sol_per_pop,
#    (...)
#      83                        suppress_warnings=True,
#      84                        gene_type=int)
#      86 # Running the GA to optimize the parameters of the function.
# ---> 87 ga_instance.run()
#      89 # Returning the details of the best solution.
#      90 self.solution, solution_fitness, solution_idx = ga_instance.best_solution(ga_instance.last_generation_fitness)
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:1914, in GA.run(self)
#    1911     generation_last_idx = self.num_generations
#    1913 # Measuring the fitness of each chromosome in the population. Save the fitness in the last_generation_fitness attribute.
# -> 1914 self.last_generation_fitness = self.cal_pop_fitness()
#    1916 best_solution, best_solution_fitness, best_match_idx = self.best_solution(pop_fitness=self.last_generation_fitness)
#    1918 # Appending the best solution in the initial population to the best_solutions list.
#
# File c:\Users\thevh\AppData\Local\Programs\Python\Python39\lib\site-packages\pygad\pygad.py:1708, in GA.cal_pop_fitness(self)
#    1705 else:
#    1706     # Check if batch processing is used. If not, then calculate this missing fitness value.
#    1707     if self.fitness_batch_size in [1, None]:
# -> 1708         fitness = self.fitness_func(self, sol, sol_idx)
#    1709         if type(fitness) in GA.supported_int_float_types:
#    1710             # The fitness function returns a single numeric value.
#    1711             # This is a single-objective optimization problem.
#    1712             pass
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\GEN_NTSK.py:166, in GEN_NTSK.genetic_algorithm(self, ga_instance, selected_cols, selected_cols_idx)
#     164 self.model = NTSK(n_clusters = self.n_clusters, lambda1 = self.lambda1, RLS_option = self.RLS_option)
#     165 # Train the model
# --> 166 self.model.fit(X_train, y_train)
#     167 # Test the model
#     168 y_pred = self.model.predict(X_val)
#
# File d:\Dissertação\dissertacao_pgmc\Cadernos\..\Modelo\NTSK.py:86, in NTSK.fit(self, X, y)
#      84 x = X[k,].reshape((1,-1)).T
#      85 # Compute xe
# ---> 86 xe = np.insert(x.T, 0, 1, axis=1).T
#      87 # # Update the rule
#      88 # self.Rule_Update(df.loc[k, m + 2])
#      89 # Compute the normalized firing level
#      90 self.weight(x)
#
# File <__array_function__ internals>:200, in insert(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\function_base.py:5406, in insert(arr, obj, values, axis)
#    5404 new[tuple(slobj)] = arr[tuple(slobj)]
#    5405 slobj[axis] = slice(index, index+numnew)
# -> 5406 new[tuple(slobj)] = values
#    5407 slobj[axis] = slice(index+numnew, None)
#    5408 slobj2 = [slice(None)] * ndim
#
# KeyboardInterrupt:
